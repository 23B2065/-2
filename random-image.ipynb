# %%
# 必要なライブラリをインポート
import numpy as np
import matplotlib.pyplot as plt

# ランダムな画像を作成（100x100のカラー画像）
random_image = np.random.rand(100, 100, 3)

# 画像として表示
plt.imshow(random_image)
plt.axis('off')  # 軸（目盛り）を非表示
plt.show()
